# %% [markdown]
# # **Machine Learning Reconstruction of Surface Ocean pCO₂**
#
# ## **Introduction**
# The ocean plays a crucial role in the global carbon cycle by absorbing atmospheric CO₂, sequestering approximately 38% of anthropogenic fossil fuel emissions. Accurate estimation of air–sea CO₂ flux is critical for understanding the global carbon budget, yet remains challenging due to the sparse and unevenly distributed nature of surface ocean pCO₂ observations. The **Surface Ocean CO₂ Atlas (SOCAT)** provides the most extensive dataset available, but its coverage is particularly limited in high-latitude regions and during winter months.
#
# To address this data sparsity, statistical and machine learning (ML) techniques have been widely used to reconstruct global pCO₂ fields by interpolating between observations using environmental predictors such as sea surface temperature (SST), sea surface salinity (SSS), mixed layer depth (MLD), chlorophyll-a (Chl-a), and atmospheric CO₂ (xCO₂). While ML methods can capture seasonal variability well, they often overestimate decadal variability, particularly in regions with limited data coverage.
#
# This study builds upon previous work by incorporating a **pCO₂-Residual** approach to improve ML-based pCO₂ reconstructions. The **pCO₂-Residual** method removes the temperature-driven component from pCO₂ before applying ML, thereby reducing the dominance of temperature in predictions and enhancing the ability of the model to capture non-temperature-driven variability. Additionally, we employ the **Large Ensemble Testbed (LET)**, which provides gridded pCO₂ output from Earth system models, allowing for a direct evaluation of ML reconstruction performance.
#
#
# We reproduce a portion of the analysis carried out by
# **Gloege et al. (2020)** *"Quantifying Errors in Observationally Based Estimates of Ocean Carbon Sink Variability."* **Global Biogeochemical Cycles** 34: e2020GB006788.
# ([DOI: 10.1029/2020GB006788](https://doi.org/10.1029/2020GB006788))
#
# and
#
# **Heimdal et al. (2024)** *"Assessing improvements in global ocean pCO₂ machine learning reconstructions with Southern Ocean autonomous sampling."* **Biogeosciences** 21: 2159–2176.
# ([DOI: 10.5194/bg-21-2159-2024](https://doi.org/10.5194/bg-21-2159-2024))
#
# Our study aims to:
# 1. Implement an **XGBoost-based pCO₂-Residual reconstruction** approach.
# 2. Evaluate reconstruction performance using **bias, and correlation metrics**.

# %% [markdown]
# # 1. Setup workspace and Import packages

# %%
# !pip install tensorflow
# !pip install keras
# Out:
# Requirement already satisfied: tensorflow in /srv/conda/envs/notebook/lib/python3.12/site-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /srv/conda/envs/notebook/lib/python3.12/site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from tensorflow) (5.27.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.12/site-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from tensorflow) (1.65.5)
# Requirement already satisfied: tensorboard~=2.19.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /srv/conda/envs/notebook/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow) (13.9.3)
# Requirement already satisfied: namex in /srv/conda/envs/notebook/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /srv/conda/envs/notebook/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from tensorboard~=2.19.0->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Requirement already satisfied: keras in /srv/conda/envs/notebook/lib/python3.12/site-packages (3.9.0)
# Requirement already satisfied: absl-py in /srv/conda/envs/notebook/lib/python3.12/site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in /srv/conda/envs/notebook/lib/python3.12/site-packages (from keras) (2.0.2)
# Requirement already satisfied: rich in /srv/conda/envs/notebook/lib/python3.12/site-packages (from keras) (13.9.3)
# Requirement already satisfied: namex in /srv/conda/envs/notebook/lib/python3.12/site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /srv/conda/envs/notebook/lib/python3.12/site-packages (from keras) (3.12.1)
# Requirement already satisfied: optree in /srv/conda/envs/notebook/lib/python3.12/site-packages (from keras) (0.14.1)
# Requirement already satisfied: ml-dtypes in /srv/conda/envs/notebook/lib/python3.12/site-packages (from keras) (0.5.1)
# Requirement already satisfied: packaging in /srv/conda/envs/notebook/lib/python3.12/site-packages (from keras) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)

# %%
### standard imports ###
import numpy as np
import pandas as pd
import xarray as xr
import gcsfs
### Python file with supporting functions ###
# standard imports
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import datetime
from pathlib import Path
from collections import defaultdict
import scipy
import json
import random
import matplotlib.pyplot as plt
import glob
pd.set_option('display.max_colwidth',100)
import joblib
import pickle
import csv
import cmocean as cm
import time

from cartopy.util import add_cyclic_point


# machine learning libraries
import sklearn            
from sklearn.metrics import make_scorer
import xgboost as xgb     
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV

cwd=os.getcwd()
parent_dir = os.path.dirname(cwd)
os.chdir(parent_dir)
cwd = parent_dir
print("Current working directory:", os.getcwd())

# Python file with supporting functions
import lib.residual_utils as supporting_functions
from lib.visualization import *
from lib.bias_figure2 import concat_datasets, XarrayEvaluator
from lib.corr_figure3 import eval_spatial
# Out:
# Current working directory: /home/jovyan/Project3
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742260363.782042    4364 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742260363.786517    4364 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1742260363.797742    4364 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1742260363.797755    4364 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1742260363.797757    4364 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1742260363.797758    4364 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
### Setting the date range to unify the date type ###

# Define date range
date_range_start = '2004-01-01T00:00:00.000000000'
# date_range_start = '1982-02-01T00:00:00.000000000'
date_range_end = '2023-12-31T00:00:00.000000000'

# create date vector, adds 14 days to start & end
dates = pd.date_range(start=date_range_start, 
                      end=date_range_end,freq='MS')


init_date = str(dates[0].year) + format(dates[0].month,'02d')
fin_date = str(dates[-1].year) + format(dates[-1].month,'02d')

# %% [markdown]
# # 2. Data Introduction and Storage

# %% [markdown]
# ## **2.1 Input (Features) Sources**
# The **input features** for the machine learning model are derived primarily from **pre-processed Earth System Model (ESM) outputs** with supplemental observational constraints where available.
#
# ### **Feature and Target Variables for the ML Model**
# The features used for training the **pCO₂-Residual machine learning model** are:
#
#
# | **Feature** | **Description** | **ESM Input or Output?** |
# |------------|----------------|----------------|
# | **SST (Sea Surface Temperature)** | Simulated ocean surface temperature | **ESM Output** |
# | **SST_anom** | SST anomaly from climatology | **ESM Output** |
# | **SSS (Sea Surface Salinity)** | Simulated surface ocean salinity | **ESM Output** |
# | **SSS_anom** | SSS anomaly from climatology | **ESM Output** |
# | **MLD_clim_log** | Log-transformed climatological mixed layer depth | **ESM Output** |
# | **Chl-a (Chlorophyll concentration)** | Proxy for biological activity (log-transformed) | **ESM Output** |
# | **Chl-a_anom** | Anomaly of Chl-a | **ESM Output** |
# | **xCO₂ (Atmospheric CO₂ concentration)** | Atmospheric CO₂ levels (forcing for ocean models) | **ESM Input** |
# | **A, B, C** | Coefficients from empirical pCO₂-temperature relationships | **Derived Variable** |
# | **T0, T1** | Temporal trend variables for pCO₂ reconstruction | **Derived Variable** |
#
#
# The **target variable** for reconstruction is:
# - **pCO₂-Residual**: This represents the deviation from the temperature-driven component of pCO₂, reducing SST's dominance in ML reconstructions and improving model performance in data-sparse regions.
#
# ### **Data Sources and Paths**
# The data is stored in a **cloud-based environment**, ensuring efficient access and scalability for the machine learning workflow. Key datasets include:
#
# - **Atmospheric xCO₂ Data**:
#   - **Description**: Provides atmospheric CO₂ concentrations from **CMIP6 models**, essential for driving the long-term trends in oceanic pCO₂.
#
# - **SOCAT Data (Mask File)**:
#   - **Description**: Masking file based on **SOCAT pCO₂ observations**, used to sample model data in a way that reflects real-world observational density.
#
# - **Topography and Land-Sea Mask**:
#   - **GEBCO Topography File**:
#     - **Description**: Global topographic dataset used to define coastal regions and provide physical constraints for model inputs.
#   - **Land-Sea Mask File**:
#     - **Description**: Binary land-sea mask used to restrict predictions to ocean regions only.
#
# ### **Key Considerations:**
# - **pCO₂-Residual Approach**: By removing the temperature-driven component from pCO₂, we enhance the ability of machine learning models to capture **non-temperature-driven variability**, particularly in poorly observed regions.
# - **Data Subsampling Based on SOCAT**: The use of a **SOCAT-derived mask** ensures that the ML model is trained and evaluated using a realistic observational distribution, mitigating potential biases from uneven data coverage.
# - **Preprocessed Model Data for Efficient Computation**: By leveraging **ensemble Earth System Model outputs**, we reduce computational overhead and ensure a globally consistent dataset for machine learning.
# - **Cloud-Based Storage**: All data files are stored in a scalable, cloud-accessible format (`.zarr`), enabling efficient data access for large-scale ML training.
#
# ### **Final Input Structure**:
# - **Feature Matrix**: `(N, 12)`, where `N` represents the number of samples, and 12 predictor variables are used.
# - **Target Variable**: `pCO₂-Residual`, which the model aims to reconstruct.

# %%
# features for ML:
features_sel = ['sst','sst_anom','sss','sss_anom','mld_clim_log','chl_log','chl_log_anom','xco2','A', 'B', 'C', 'T0', 'T1']

# the target variable we reconstruct:
target_sel = ['pco2_residual'] # this represents pCO2 - pCO2_T (calculated in notebook 00)

# %%
### set up for getting files from leap bucket ###
fs = gcsfs.GCSFileSystem()

### set paths ###

### paths for loading: ###
# directory of regridded members from notebook 00
ensemble_dir = "gs://leap-persistent/abbysh/pco2_all_members_1982-2023/00_regridded_members" # path to regridded data
path_seeds = "gs://leap-persistent/abbysh/pickles/random_seeds.npy" # random seeds for ML

# directory of reference zarr files
zarr_dir = 'gs://leap-persistent/abbysh/zarr_files_'

# atmospheric xco2 file
xco2_path = f"{zarr_dir}/xco2_cmip6_183501-224912_monthstart.zarr"

# socat data file
socat_path = f"{zarr_dir}/socat_mask_feb1982-dec2023.zarr"

# topo and land-sea masks
topo_path = f"{zarr_dir}/GEBCO_2014_1x1_global.zarr"
lsmask_path = f"{zarr_dir}/lsmask.zarr"

#############################################

your_username = ''

# where machine learning inputs are saved
MLinputs_path = f"gs://leap-persistent/{your_username}/pco2_residual/post01_xgb_inputs"

# %% [markdown]
# ### **Output Data Storage and Model Saving**
#
# The output data generated by this notebook, including model predictions, performance metrics, and trained models, is saved in a cloud-based environment using a user-specific directory structure. This ensures that each user’s results are organized and accessible without interfering with others’ work.
#
# The output data is organized into three main categories:
# 1. **Machine Learning Models:** Trained models are saved for future use, ensuring that results can be replicated without re-training.
# 2. **Reconstructions:** Predicted pCO₂ fields are stored for further analysis and visualization.
# 3. **Performance Metrics:** CSV files containing test and unseen data performance metrics are saved for easy evaluation.

# %%
grid_search_approach = 'nmse'
output_dir = f'gs://leap-persistent/{your_username}/pco2_residual/{grid_search_approach}/post02_xgb' # where to save machine learning results

model_output_dir = f"{output_dir}/trained" # where to save ML models
recon_output_dir = f"{output_dir}/reconstructions" # where to save ML reconstructions

metrics_output_dir = f'{output_dir}/metrics' # where to save performance metrics
test_perform_fname = f"{metrics_output_dir}/xgb_test_performance_{init_date}-{fin_date}.csv" # path for test performance metrics
unseen_perform_fname = f"{metrics_output_dir}/xgb_unseen_performance_{init_date}-{fin_date}.csv" # path for unseen performance metrics

xgb_model_save_dir = f'{output_dir}/saved_models_{init_date}-{fin_date}' # where to save .json model file

# %% [markdown]
# # 3.  **Earth System Models ( Ensemble Members)**
# This notebook utilizes data from multiple Earth System Models (ESMs) that are part of the **Large Ensemble Testbed (LET)**. The LET originally includes **100 ensemble members** from different SEM, each representing unique initial conditions. These ensemble members are crucial for capturing internal climate variability and assessing model uncertainty.
#
# However, to optimize computational efficiency and simplify machine learning workflows, we select some representative member from the first three ESM. If desired, you can modify the `mems_dict` variable to include more members from each ESM. This flexibility allows for expanded analyses while maintaining the structure of this notebook.

# %%
ensembles = []
for path in fs.ls(ensemble_dir):
    ens = path.split('/')[-1].split('.')[0]
    if ens not in ensembles:
        ensembles.append(ens)

mems_dict = dict()
a = fs.ls(ensemble_dir)
for ens_path in a[1:4]:               ## not include 00_regridded_members/ dictionary , only choose the first three ESM here.
    ens = ens_path.split('/')[-1]
    mems = fs.ls(ens_path)
    for mem in mems:        
        memo = mem.split('/')[-1]
        if ens not in mems_dict:
            mems_dict[ens] = [memo]
        elif ens in mems_dict:
            mems_dict[ens].append(memo)

# %%
random.seed(42)  # Set seed for reproducibility

selected_mems_dict = {}

num_members = 3  # Set the number of members to select for each ensemble

for ens, members in mems_dict.items():
    if len(members) >= num_members:
        selected_mems_dict[ens] = random.sample(members, num_members)  # Select `num_members` random members
    else:
        selected_mems_dict[ens] = members  # If there are fewer members than `num_members`, select all

print(selected_mems_dict)
# Out:
# {'ACCESS-ESM1-5': ['member_r5i1p1f1', 'member_r1i1p1f1', 'member_r10i1p1f1'], 'CESM2': ['member_r4i1p1f1', 'member_r11i1p1f1', 'member_r10i1p1f1'], 'CESM2-WACCM': ['member_r1i1p1f1', 'member_r3i1p1f1', 'member_r2i1p1f1']}

# %% [markdown]
# ## Processing and Saving ESM Data for ML
#
# In this step, we extract the required ML data from ESM datasets stored in **Google Cloud Storage (GCS)**. The extracted data is structured into Pandas DataFrames and saved under our **own username-specific workspace** in GCS. This ensures that we have direct access to preprocessed data for ML experiments.
#
# Similarly, the ML output results are also stored under our own username-specific directory in GCS. This means that even if you exit and re-enter JupyterHub, your data will remain available, eliminating the need for reprocessing.
#
# ### **Important Note: Run This Only Once**
#
# The **data extraction and processing** step needs to be run **only once** per project, unless new data is required. This helps save computational resources and execution time.
#
# For each **ensemble member**, the estimated runtime is:
# - **1.32 minutes** for data retrieval and processing.
# - **4 minutes** for XGBoost ML training.
# - **Total estimated time**: **5.3 × (total number of selected members)** min.
#
# With a **128GB CPU**, actual runtimes may vary based on system load and selected members, but this serves as a general guideline.
#
# ### Before Running Again:
# Before executing the data processing or ML training steps again, **check whether you actually need new data**. If not, avoid redundant computations to optimize resource usage. You can also check the storage under the path constantly to clear redundant usage.

# %%
### creating pandas dataframes out of "raw" data to prep for ML ###
N_time = len(dates)
member_counter = 0 

### loop through each ESM
for ens, mem_list in selected_mems_dict.items(): 

    ### loop through each member of that ESM
    for member in mem_list:
        
        print(f'making dataframe {member_counter}: {ens,member}')

        ### uses utility function file to make data into dataframe for ML use
        df = supporting_functions.create_inputs(ensemble_dir, ens, member, dates, N_time,
                                  xco2_path,
                                  socat_path,
                                  topo_path,
                                  lsmask_path)

        ### Save the pandas dataframe to workspace
        supporting_functions.save_clean_data(df, MLinputs_path, ens, member, dates)
        member_counter += 1
# Out:
# making dataframe 0: ('ACCESS-ESM1-5', 'member_r5i1p1f1')
# Starting data saving process
# member_r5i1p1f1 save complete
# making dataframe 1: ('ACCESS-ESM1-5', 'member_r1i1p1f1')
# Starting data saving process
# member_r1i1p1f1 save complete
# making dataframe 2: ('ACCESS-ESM1-5', 'member_r10i1p1f1')
# Starting data saving process
# member_r10i1p1f1 save complete
# making dataframe 3: ('CESM2', 'member_r4i1p1f1')
# Starting data saving process
# member_r4i1p1f1 save complete
# making dataframe 4: ('CESM2', 'member_r11i1p1f1')
# Starting data saving process
# member_r11i1p1f1 save complete
# making dataframe 5: ('CESM2', 'member_r10i1p1f1')
# Starting data saving process
# member_r10i1p1f1 save complete
# making dataframe 6: ('CESM2-WACCM', 'member_r1i1p1f1')
# Starting data saving process
# member_r1i1p1f1 save complete
# making dataframe 7: ('CESM2-WACCM', 'member_r3i1p1f1')
# Starting data saving process
# member_r3i1p1f1 save complete
# making dataframe 8: ('CESM2-WACCM', 'member_r2i1p1f1')
# Starting data saving process
# member_r2i1p1f1 save complete
# Total execution time: 490.25 seconds

# %% [markdown]
# We save the data in a Google Cloud Storage (GCS) directory. We can use the following command to list the contents of the folder:

# %%
import gcsfs

fs = gcsfs.GCSFileSystem()
ens0 = 'ACCESS-ESM1-5'
member_dir = f"{ensemble_dir}/{ens0}/{selected_mems_dict[ens0][0]}"
files = fs.ls(member_dir)

print("Files in GCS directory:")
for file in files:
    print(file)
# Out:
# Files in GCS directory:
# leap-persistent/abbysh/pco2_all_members_1982-2023/00_regridded_members/ACCESS-ESM1-5/member_r5i1p1f1/ACCESS-ESM1-5.r5i1p1f1.Omon.zarr
# leap-persistent/abbysh/pco2_all_members_1982-2023/00_regridded_members/ACCESS-ESM1-5/member_r5i1p1f1/chlclim_ACCESS-ESM1-5.r5i1p1f1.Omon.zarr

# %% [markdown]
# Unlike the sparse observational data, Earth System Model (ESM) outputs provide continuous global coverage of climate variables. To better understand the observational constraints, we apply a SOCAT-based mask to the ESM data. This mask mimics the data sparsity of real-world observations by selectively masking regions where SOCAT observations are absent. The SOCAT mask varies over time, reflecting the temporal evolution of observational coverage.
#
# Using this mask, we process all ESM data to generate a sparse dataset that requires reconstruction, where the unmasked regions serve as the ground truth for evaluating reconstruction accuracy.
#
# In this figure, we visualize the pCO₂ field from a selected ensemble member of an ESM for a specific time period, applying the SOCAT mask to illustrate how the data coverage changes.

# %%
ens0 = 'ACCESS-ESM1-5'
member_dir = f"{ensemble_dir}/{ens0}/{selected_mems_dict[ens0][0]}"
member_path = fs.glob(f"{member_dir}/*.zarr")[0]
chl_clim_path = fs.glob(f"{member_dir}/chlclim*.zarr")[0]
file_engine = 'zarr'
member_data = xr.open_mfdataset('gs://'+member_path, engine=file_engine).sel(time=slice(str(dates[0]),str(dates[-1])))
socat_mask_data = xr.open_mfdataset(socat_path, engine=file_engine).sel(time=slice(str(dates[0]),str(dates[-1])))
tmp = xr.open_mfdataset('gs://'+chl_clim_path, engine=file_engine).chl_clim
xco2 = xr.open_mfdataset(xco2_path, engine=file_engine).sel(time=slice(str(dates[0]),str(dates[-1])))

# %%
plot_style = "seaborn-v0_8-talk"

cmap = cm.cm.thermal
cbar_title = 'pCO₂ (µatm)'
vrange = [280, 440]  # Ensure correct range format

with plt.style.context(plot_style):
    fig = plt.figure(figsize=(8.5, 11)) 
    worldmap = SpatialMap2(fig=fig, region='world', 
                           cbar_mode='each',
                           colorbar=True,  # Enable colorbar
                           cbar_location='bottom',
                           nrows_ncols=[1,1])
    
    chosen_time = '2021-01'
    data = member_data["spco2"].sel(time=chosen_time).squeeze()
    data = xr_add_cyclic_point(data, cyclic_coord='xlon')    
    mask = socat_mask_data.sel(time=chosen_time)["socat_mask"].squeeze()
    mask = xr_add_cyclic_point(mask, cyclic_coord='xlon')    
    masked_data = np.ma.masked_array(data, mask=(mask == 0))  # Mask where mask==0

    data = data.assign_coords(xlon=(((data.xlon + 180) % 360) - 180))
    mask = mask.assign_coords(xlon=(((mask.xlon + 180) % 360) - 180))

    sub = worldmap.add_plot(lon=data['xlon'], 
                            lat=data['ylat'], 
                            data=masked_data,
                            vrange=vrange,  # Corrected vrange
                            cmap=cmap, 
                            ax=0)

    # Add colorbar properly
    colorbar = worldmap.add_colorbar(sub, ax=0)
    worldmap.set_cbar_ylabel(colorbar, cbar_title, fontsize=12)

    # Add title
    worldmap.set_title("SOCAT Masked pCO₂ Data for 2021-01", ax=0, fontsize=14)

    plt.show()

# %% [markdown]
# We can adjust the values of chosen_time and ens0 to explore different available data, which helps us better understand the masked ESM data that will be used in the following machine learning work.

# %% [markdown]
# # 4. ML Reconstruction

# %% [markdown]
# ## 4.1 Data Split
#
# We split data to training data set and testing dataset based on date.

# %%
### train-validate-test split proportions ###

select_dates = []
test_dates = []

for i in range(0,len(dates)):
    if i % 5 != 0:
        select_dates.append(dates[i]) ### 80% train days set ###
    if i % 5 == 0:
        test_dates.append(dates[i]) ### 20% test days set ### 

### Then, the month numbers above are converted back to their respective datetime objects.

year_mon = []

for i in range(0,len(select_dates)):
    
    tmp = select_dates[i]
    year_mon.append(f"{tmp.year}-{tmp.month}")
    
test_year_mon = []

for i in range(0,len(test_dates)):
    
    tmp = test_dates[i]
    test_year_mon.append(f"{tmp.year}-{tmp.month}")

# %% [markdown]
# ## 4.2 Hyperparameters

# %%
params = {
    'n_estimators': 500,  # Number of boosting rounds
    'max_depth': 6,  # Maximum depth of each tree to control model complexity
    'learning_rate': 0.05,  # Step size shrinkage to prevent overfitting
    'subsample': 0.8,  # Fraction of samples used for training each tree
    'colsample_bytree': 0.8,  # Fraction of features used per tree
    'gamma': 0.1,  # Minimum loss reduction required for further partitioning
    'min_child_weight': 5,  # Minimum sum of instance weight in a leaf node
    'reg_alpha': 0.1,  # L1 regularization to reduce model complexity
    'reg_lambda': 1.0,  # L2 regularization for preventing overfitting
    'objective': 'reg:squarederror',  # Loss function for regression tasks
    'n_jobs': 30,  # Number of parallel threads to use for training
    'eval_metric': 'rmse',
    'early_stopping_rounds': 50  # Stop training if performance doesn't improve for 50 rounds
}

# %% [markdown]
# ## 4.2 ML - XGBoost
#
# ### Important Note: Run This Only Once
#
# The **ML Reconstruction** step needs to be run **only once** per project, unless new modeling is required. This helps save computational resources and execution time.

# %%
random_seeds = np.load(fs.open(path_seeds))   

seed_loc_dict = defaultdict(dict)
for ens,mem_list in mems_dict.items():
    sub_dictt = dict()
    for no,mem in enumerate(mem_list):
        sub_dictt.update({mem:no})
    seed_loc_dict.update({ens:sub_dictt})

val_prop = .2 # 20% of training data for validation
test_prop = .0 # Since we apply this split to X_train, we set it to zero. We have X_test as testing dataset.

print(datetime.datetime.now())


for ens, mem_list in selected_mems_dict.items():
    for member in mem_list:
        print(ens, member)
        seed_loc = seed_loc_dict[ens][member]
        data_dir = f"{MLinputs_path}/{ens}/{member}"
        fname = f"MLinput_{ens}_{member.split('_')[-1]}_mon_1x1_{init_date}_{fin_date}.pkl"
        file_path = f"{data_dir}/{fname}"

        with fs.open(file_path, 'rb') as filee:
            df = pd.read_pickle(filee)
            df['year'] = df.index.get_level_values('time').year
            df['mon'] = df.index.get_level_values('time').month
            df['year_month'] = df['year'].astype(str) + "-" + df['mon'].astype(str)
            
            recon_sel = (
                ~df[features_sel+target_sel+['net_mask']].isna().any(axis=1)
            ) & (
                (df[target_sel] < 250) & (df[target_sel] > -250)
            ).to_numpy().ravel()

            sel = (recon_sel & (df['socat_mask'] == 1))
            
            train_sel = (sel & (pd.Series(df['year_month']).isin(year_mon))).to_numpy().ravel()
            test_sel  = (sel & (pd.Series(df['year_month']).isin(test_year_mon))).to_numpy().ravel()
            unseen_sel = (recon_sel & (df['socat_mask'] == 0))

            X = df.loc[sel, features_sel].to_numpy()
            y = df.loc[sel, target_sel].to_numpy().ravel()

            Xtrain = df.loc[train_sel, features_sel].to_numpy()                
            ytrain = df.loc[train_sel, target_sel].to_numpy().ravel()

            X_test = df.loc[test_sel, features_sel].to_numpy()
            y_test = df.loc[test_sel, target_sel].to_numpy().ravel()
            N = Xtrain.shape[0]
            
            train_val_idx, train_idx, val_idx, test_idx = supporting_functions.train_val_test_split(
                N, test_prop, val_prop, random_seeds, seed_loc
            )
            X_train_val, X_train, X_val, X_test_tmp, y_train_val, y_train, y_val, y_test_tmp = \
                supporting_functions.apply_splits(Xtrain, ytrain, train_val_idx, train_idx, val_idx, test_idx)   

        train_performance = defaultdict(dict)
        test_performance = defaultdict(dict)
        unseen_performance = defaultdict(dict)

        model = XGBRegressor(
            random_state=random_seeds[5, seed_loc],
            **params,
        )
        eval_set = [(X_val, y_val)] 
        model.fit(
            X_train_val, y_train_val, 
            eval_set=eval_set, 
            verbose=False
        )

        supporting_functions.save_model(model, dates, xgb_model_save_dir, ens, member)

        y_pred_test = model.predict(X_test)
      
        test_performance[ens][member] = supporting_functions.evaluate_test(y_test, y_pred_test)

        fields = test_performance[ens][member].keys()
        test_row_dict = dict()
        test_row_dict['model'] = ens
        test_row_dict['member'] = member
        
        for field in fields:
            test_row_dict[field] = test_performance[ens][member][field]

        file_exists = fs.exists(test_perform_fname)
        with fs.open(test_perform_fname, 'a') as f_object:
            writer = csv.DictWriter(f_object, fieldnames=test_row_dict.keys())
            if not file_exists:
                writer.writeheader() 
            writer.writerow(test_row_dict)
        print('test performance metrics:', test_performance[ens][member])
        
        y_pred_unseen = model.predict(df.loc[unseen_sel, features_sel].to_numpy())
        y_unseen = df.loc[unseen_sel, target_sel].to_numpy().ravel()
        unseen_performance[ens][member] = supporting_functions.evaluate_test(y_unseen, y_pred_unseen)

        fields = unseen_performance[ens][member].keys()
        unseen_row_dict = dict()
        unseen_row_dict['model'] = ens
        unseen_row_dict['member'] = member
        
        for field in fields:
            unseen_row_dict[field] = unseen_performance[ens][member][field]

        file_exists = fs.exists(unseen_perform_fname)
        with fs.open(unseen_perform_fname, 'a') as f_object:
            writer = csv.DictWriter(f_object, fieldnames=unseen_row_dict.keys())
            if not file_exists:
                writer.writeheader() 
            writer.writerow(unseen_row_dict)

        print('unseen performance metrics:', unseen_performance[ens][member])

        y_pred_seen = model.predict(X)
        
        df['pCO2_recon_full'] = np.nan
    
        df.loc[unseen_sel, 'pCO2_recon_full'] = y_pred_unseen 
        df.loc[sel, 'pCO2_recon_full'] = y_pred_seen

        df['pCO2_recon_test'] = np.nan
        df.loc[unseen_sel, 'pCO2_recon_test'] = np.nan
        df.loc[sel, 'pCO2_recon_test'] = y_pred_seen
        df.loc[train_sel, 'pCO2_recon_test'] = np.nan

        df['pCO2_recon_train'] = np.nan
        df.loc[unseen_sel, 'pCO2_recon_train'] = np.nan
        df.loc[sel, 'pCO2_recon_train'] = y_pred_seen
        df.loc[test_sel, 'pCO2_recon_train'] = np.nan

        df['pCO2_recon_unseen'] = np.nan
        df.loc[unseen_sel, 'pCO2_recon_unseen'] = y_pred_unseen
        df.loc[sel, 'pCO2_recon_unseen'] = np.nan

        
        df['pCO2_truth'] = df.loc[:,target_sel]

        df['pCO2_recon_socat'] = np.nan
        df.loc[unseen_sel, 'pCO2_recon_socat'] = np.nan
        df.loc[sel, 'pCO2_recon_socat'] = y_pred_seen

        df['pCO2_residual_testbed_truth'] = df['pco2_residual']

        DS_recon = df[[
            'net_mask','socat_mask','pCO2_residual_testbed_truth','pCO2_recon_full',
            'pCO2_recon_socat','pCO2_recon_unseen', 'pCO2_recon_test','pCO2_recon_train', 'pCO2_truth'
        ]].to_xarray()

    
        supporting_functions.save_recon(DS_recon, dates, recon_output_dir, ens, member)
        print('end of member', datetime.datetime.now())
        
print('end of all members', datetime.datetime.now())
# Out:
# 2025-03-17 22:30:13.137622
# ACCESS-ESM1-5 member_r5i1p1f1
# Starting model saving process...
# Model successfully uploaded to GCS: gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/saved_models_200401-202312/model_pC02_2D_ACCESS-ESM1-5_r5i1p1f1_mon_1x1_200401_202312.json
# Model saving process complete.
# test performance metrics: {'mse': np.float64(74.81590486183161), 'mae': np.float64(5.915016338927556), 'medae': np.float64(4.19636547411335), 'max_error': np.float64(140.4208275620498), 'bias': np.float64(-0.4444637554838806), 'r2': 0.8825246433184988, 'corr': np.float64(0.9401928626056572), 'cent_rmse': np.float64(8.638191825347553), 'stdev': np.float32(22.87938), 'amp_ratio': np.float64(0.7669258846762146), 'stdev_ref': np.float64(25.236177901400776), 'range_ref': np.float64(379.1600922842119), 'iqr_ref': np.float64(28.925005432783962)}
# unseen performance metrics: {'mse': np.float64(114.07812169296368), 'mae': np.float64(7.10751666589069), 'medae': np.float64(5.0346182847890475), 'max_error': np.float64(218.20154250637927), 'bias': np.float64(-0.0753284495020452), 'r2': 0.8348052820249998, 'corr': np.float64(0.9151423978964455), 'cent_rmse': np.float64(10.680470310482656), 'stdev': np.float32(22.690304), 'amp_ratio': np.float64(0.801495115260102), 'stdev_ref': np.float64(26.27865313718119), 'range_ref': np.float64(497.4031926803089), 'iqr_ref': np.float64(29.863725255251126)}
# Starting reconstruction saving process
# gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/reconstructions/ACCESS-ESM1-5/member_r5i1p1f1/recon_pC02residual_ACCESS-ESM1-5_member_r5i1p1f1_mon_1x1_200401_202312.zarr
# Save complete
# end of member 2025-03-17 22:31:10.076559
# ACCESS-ESM1-5 member_r1i1p1f1
# Starting model saving process...
# Model successfully uploaded to GCS: gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/saved_models_200401-202312/model_pC02_2D_ACCESS-ESM1-5_r1i1p1f1_mon_1x1_200401_202312.json
# Model saving process complete.
# test performance metrics: {'mse': np.float64(81.35768928098729), 'mae': np.float64(6.169469722018384), 'medae': np.float64(4.326730540209951), 'max_error': np.float64(116.28821887855571), 'bias': np.float64(-0.007422246648147279), 'r2': 0.8841112166648082, 'corr': np.float64(0.9405966397472303), 'cent_rmse': np.float64(9.01984667562909), 'stdev': np.float32(24.26715), 'amp_ratio': np.float64(0.7597835970987402), 'stdev_ref': np.float64(26.495895419163944), 'range_ref': np.float64(464.6904056594619), 'iqr_ref': np.float64(29.805282300946033)}
# unseen performance metrics: {'mse': np.float64(121.45743329037363), 'mae': np.float64(7.356331380297926), 'medae': np.float64(5.200030507922406), 'max_error': np.float64(219.1321969313928), 'bias': np.float64(-0.28068360633782063), 'r2': 0.8344999143283607, 'corr': np.float64(0.9149465204455067), 'cent_rmse': np.float64(11.01719795562572), 'stdev': np.float32(23.426243), 'amp_ratio': np.float64(0.7899486363640829), 'stdev_ref': np.float64(27.090245333903265), 'range_ref': np.float64(498.94238288021097), 'iqr_ref': np.float64(30.406101704032906)}
# Starting reconstruction saving process
# gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/reconstructions/ACCESS-ESM1-5/member_r1i1p1f1/recon_pC02residual_ACCESS-ESM1-5_member_r1i1p1f1_mon_1x1_200401_202312.zarr
# Save complete
# end of member 2025-03-17 22:32:15.499430
# ACCESS-ESM1-5 member_r10i1p1f1
# Starting model saving process...
# Model successfully uploaded to GCS: gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/saved_models_200401-202312/model_pC02_2D_ACCESS-ESM1-5_r10i1p1f1_mon_1x1_200401_202312.json
# Model saving process complete.
# test performance metrics: {'mse': np.float64(81.47548634691786), 'mae': np.float64(6.12175474842909), 'medae': np.float64(4.2654884627369825), 'max_error': np.float64(160.5281192580075), 'bias': np.float64(-0.4055855434840989), 'r2': 0.872474796209209, 'corr': np.float64(0.9348800016651522), 'cent_rmse': np.float64(9.017260447883126), 'stdev': np.float32(22.730225), 'amp_ratio': np.float64(0.7525555888519803), 'stdev_ref': np.float64(25.27641444499581), 'range_ref': np.float64(412.80027146046496), 'iqr_ref': np.float64(27.86953780185027)}
# unseen performance metrics: {'mse': np.float64(118.21537428547731), 'mae': np.float64(7.166210330564112), 'medae': np.float64(5.061299995733634), 'max_error': np.float64(244.1274619397692), 'bias': np.float64(-0.10246250732306805), 'r2': 0.8322454473638496, 'corr': np.float64(0.9132771605697432), 'cent_rmse': np.float64(10.872206623408667), 'stdev': np.float32(23.113016), 'amp_ratio': np.float64(0.8852817676657956), 'stdev_ref': np.float64(26.546044813542643), 'range_ref': np.float64(499.3369458048631), 'iqr_ref': np.float64(28.91448269017843)}
# Starting reconstruction saving process
# gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/reconstructions/ACCESS-ESM1-5/member_r10i1p1f1/recon_pC02residual_ACCESS-ESM1-5_member_r10i1p1f1_mon_1x1_200401_202312.zarr
# Save complete
# end of member 2025-03-17 22:33:16.204929
# CESM2 member_r4i1p1f1
# Starting model saving process...
# Model successfully uploaded to GCS: gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/saved_models_200401-202312/model_pC02_2D_CESM2_r4i1p1f1_mon_1x1_200401_202312.json
# Model saving process complete.
# test performance metrics: {'mse': np.float64(59.97155550745774), 'mae': np.float64(5.496667776188954), 'medae': np.float64(3.970246890760052), 'max_error': np.float64(59.86065853690059), 'bias': np.float64(-0.1188566089496721), 'r2': 0.9465629066696386, 'corr': np.float64(0.9729671766679097), 'cent_rmse': np.float64(7.743218251934739), 'stdev': np.float32(32.27772), 'amp_ratio': np.float64(0.8590215648186704), 'stdev_ref': np.float64(33.50049647001919), 'range_ref': np.float64(335.97809249263173), 'iqr_ref': np.float64(38.023071665813916)}
# unseen performance metrics: {'mse': np.float64(85.44979484407816), 'mae': np.float64(6.525325046551924), 'medae': np.float64(4.673355795134853), 'max_error': np.float64(135.15943797569008), 'bias': np.float64(0.2148593983055438), 'r2': 0.8968257523842712, 'corr': np.float64(0.9471726789650143), 'cent_rmse': np.float64(9.241408312397635), 'stdev': np.float32(26.799122), 'amp_ratio': np.float64(0.9207186821489495), 'stdev_ref': np.float64(28.77861285806043), 'range_ref': np.float64(393.84384372355134), 'iqr_ref': np.float64(32.60592354252225)}
# Starting reconstruction saving process
# gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/reconstructions/CESM2/member_r4i1p1f1/recon_pC02residual_CESM2_member_r4i1p1f1_mon_1x1_200401_202312.zarr
# Save complete
# end of member 2025-03-17 22:34:11.331189
# CESM2 member_r11i1p1f1
# Starting model saving process...
# Model successfully uploaded to GCS: gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/saved_models_200401-202312/model_pC02_2D_CESM2_r11i1p1f1_mon_1x1_200401_202312.json
# Model saving process complete.
# test performance metrics: {'mse': np.float64(60.54966654482478), 'mae': np.float64(5.561510776602834), 'medae': np.float64(4.014161553668259), 'max_error': np.float64(69.13733743651068), 'bias': np.float64(-0.27371260194447444), 'r2': 0.944967583508088, 'corr': np.float64(0.9722698732441952), 'cent_rmse': np.float64(7.776551127463612), 'stdev': np.float32(31.702185), 'amp_ratio': np.float64(1.0067863641284203), 'stdev_ref': np.float64(33.170085140395905), 'range_ref': np.float64(275.81838157618745), 'iqr_ref': np.float64(37.06112513329094)}
# unseen performance metrics: {'mse': np.float64(88.03583192955197), 'mae': np.float64(6.579569790395522), 'medae': np.float64(4.656603224090759), 'max_error': np.float64(147.89318923001514), 'bias': np.float64(0.3064682923858868), 'r2': 0.8909976211386067, 'corr': np.float64(0.9441227596632544), 'cent_rmse': np.float64(9.377734730904544), 'stdev': np.float32(26.378395), 'amp_ratio': np.float64(0.7977189762985736), 'stdev_ref': np.float64(28.419193449811996), 'range_ref': np.float64(394.9720008143843), 'iqr_ref': np.float64(31.7888788378595)}
# Starting reconstruction saving process
# gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/reconstructions/CESM2/member_r11i1p1f1/recon_pC02residual_CESM2_member_r11i1p1f1_mon_1x1_200401_202312.zarr
# Save complete
# end of member 2025-03-17 22:35:10.277815
# CESM2 member_r10i1p1f1
# Starting model saving process...
# Model successfully uploaded to GCS: gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/saved_models_200401-202312/model_pC02_2D_CESM2_r10i1p1f1_mon_1x1_200401_202312.json
# Model saving process complete.
# test performance metrics: {'mse': np.float64(61.93388414986164), 'mae': np.float64(5.571716492898306), 'medae': np.float64(3.962640944566317), 'max_error': np.float64(78.86761524323953), 'bias': np.float64(0.12457015666709825), 'r2': 0.9456350604636835, 'corr': np.float64(0.9726079835198038), 'cent_rmse': np.float64(7.868822427853319), 'stdev': np.float32(32.226337), 'amp_ratio': np.float64(0.9733203297736174), 'stdev_ref': np.float64(33.752403481279636), 'range_ref': np.float64(290.5943932454879), 'iqr_ref': np.float64(38.3052054459165)}
# unseen performance metrics: {'mse': np.float64(93.78022798704619), 'mae': np.float64(6.768857060793866), 'medae': np.float64(4.74948087840562), 'max_error': np.float64(141.69114674734828), 'bias': np.float64(0.11963423949963747), 'r2': 0.8896651609492722, 'corr': np.float64(0.9434123551336692), 'cent_rmse': np.float64(9.683280121952695), 'stdev': np.float32(26.962914), 'amp_ratio': np.float64(0.7268752209466016), 'stdev_ref': np.float64(29.154077853230927), 'range_ref': np.float64(419.6529618360419), 'iqr_ref': np.float64(34.17486682958673)}
# Starting reconstruction saving process
# gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/reconstructions/CESM2/member_r10i1p1f1/recon_pC02residual_CESM2_member_r10i1p1f1_mon_1x1_200401_202312.zarr
# Save complete
# end of member 2025-03-17 22:36:14.299081
# CESM2-WACCM member_r1i1p1f1
# Starting model saving process...
# Model successfully uploaded to GCS: gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/saved_models_200401-202312/model_pC02_2D_CESM2-WACCM_r1i1p1f1_mon_1x1_200401_202312.json
# Model saving process complete.
# test performance metrics: {'mse': np.float64(66.53147590289845), 'mae': np.float64(5.700234246927552), 'medae': np.float64(4.041937242140307), 'max_error': np.float64(85.19790540304774), 'bias': np.float64(-0.42824571462962346), 'r2': 0.939282103547815, 'corr': np.float64(0.9692766165491786), 'cent_rmse': np.float64(8.145433128909563), 'stdev': np.float32(31.85648), 'amp_ratio': np.float64(0.9128225702791275), 'stdev_ref': np.float64(33.10207514817874), 'range_ref': np.float64(301.335746411846), 'iqr_ref': np.float64(37.50120247226491)}
# unseen performance metrics: {'mse': np.float64(86.45382985171112), 'mae': np.float64(6.578320274188235), 'medae': np.float64(4.6936133312221955), 'max_error': np.float64(140.7827141064161), 'bias': np.float64(0.4157586654310865), 'r2': 0.8961015666920547, 'corr': np.float64(0.946776929217052), 'cent_rmse': np.float64(9.288754873241908), 'stdev': np.float32(27.057325), 'amp_ratio': np.float64(0.9117070370507522), 'stdev_ref': np.float64(28.84613416322589), 'range_ref': np.float64(374.4665382649305), 'iqr_ref': np.float64(32.15928809654801)}
# Starting reconstruction saving process
# gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/reconstructions/CESM2-WACCM/member_r1i1p1f1/recon_pC02residual_CESM2-WACCM_member_r1i1p1f1_mon_1x1_200401_202312.zarr
# Save complete
# end of member 2025-03-17 22:37:17.252022
# CESM2-WACCM member_r3i1p1f1
# Starting model saving process...
# Model successfully uploaded to GCS: gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/saved_models_200401-202312/model_pC02_2D_CESM2-WACCM_r3i1p1f1_mon_1x1_200401_202312.json
# Model saving process complete.
# test performance metrics: {'mse': np.float64(59.51290741968353), 'mae': np.float64(5.525118759998909), 'medae': np.float64(3.948517183492527), 'max_error': np.float64(72.905396456939), 'bias': np.float64(-0.12742171506921984), 'r2': 0.9464049062223127, 'corr': np.float64(0.9729029115541996), 'cent_rmse': np.float64(7.713408498545453), 'stdev': np.float32(32.054104), 'amp_ratio': np.float64(0.8312441061585252), 'stdev_ref': np.float64(33.32292120822225), 'range_ref': np.float64(321.7375153082585), 'iqr_ref': np.float64(36.6129720686891)}
# unseen performance metrics: {'mse': np.float64(90.84390393094296), 'mae': np.float64(6.636728958507656), 'medae': np.float64(4.657999684477147), 'max_error': np.float64(163.8265025650814), 'bias': np.float64(-0.04928594806771969), 'r2': 0.8929958921598078, 'corr': np.float64(0.9451699025576968), 'cent_rmse': np.float64(9.531079389196503), 'stdev': np.float32(26.996521), 'amp_ratio': np.float64(0.7212959410704591), 'stdev_ref': np.float64(29.137190236798126), 'range_ref': np.float64(416.92983453778334), 'iqr_ref': np.float64(32.59194147549353)}
# Starting reconstruction saving process
# gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/reconstructions/CESM2-WACCM/member_r3i1p1f1/recon_pC02residual_CESM2-WACCM_member_r3i1p1f1_mon_1x1_200401_202312.zarr
# Save complete
# end of member 2025-03-17 22:38:15.102912
# CESM2-WACCM member_r2i1p1f1
# Starting model saving process...
# Model successfully uploaded to GCS: gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/saved_models_200401-202312/model_pC02_2D_CESM2-WACCM_r2i1p1f1_mon_1x1_200401_202312.json
# Model saving process complete.
# test performance metrics: {'mse': np.float64(60.7203921775447), 'mae': np.float64(5.621542540251335), 'medae': np.float64(4.112831879990466), 'max_error': np.float64(75.09047057718129), 'bias': np.float64(-0.16608012138432926), 'r2': 0.9440509186244246, 'corr': np.float64(0.9716932114149771), 'cent_rmse': np.float64(7.7905589951536705), 'stdev': np.float32(31.663403), 'amp_ratio': np.float64(0.9177773567079361), 'stdev_ref': np.float64(32.94358086123945), 'range_ref': np.float64(301.8197767781107), 'iqr_ref': np.float64(38.47380603765542)}
# unseen performance metrics: {'mse': np.float64(90.57852271269873), 'mae': np.float64(6.66549066794626), 'medae': np.float64(4.730487106138241), 'max_error': np.float64(144.78784114573637), 'bias': np.float64(0.052014327774282165), 'r2': 0.8945704929793624, 'corr': np.float64(0.9459787616367842), 'cent_rmse': np.float64(9.517132772592532), 'stdev': np.float32(27.218124), 'amp_ratio': np.float64(0.7540957495917285), 'stdev_ref': np.float64(29.31106028859512), 'range_ref': np.float64(433.8641074728739), 'iqr_ref': np.float64(32.78108702242994)}
# Starting reconstruction saving process
# gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/reconstructions/CESM2-WACCM/member_r2i1p1f1/recon_pC02residual_CESM2-WACCM_member_r2i1p1f1_mon_1x1_200401_202312.zarr
# Save complete
# end of member 2025-03-17 22:39:14.246944
# end of all members 2025-03-17 22:39:14.247064
# Total execution time: 541.23 seconds

# %% [markdown]
# ## 5 Evaluation

# %% [markdown]
# ## 5.1 Reconstruction bias and sampling density

# %% [markdown]
# ### Add Tempearature back to pco2 residual

# %%
supporting_functions.calc_recon_pco2(ensemble_dir, recon_output_dir, selected_mems_dict, init_date, fin_date)
# Out:
# Current ESM: ACCESS-ESM1-5
# On member member_r5i1p1f1
# pco2T path: gs://leap-persistent/abbysh/pco2_all_members_1982-2023/00_regridded_members/ACCESS-ESM1-5/member_r5i1p1f1/ACCESS-ESM1-5.r5i1p1f1.Omon.zarr
# pco2D path: gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/reconstructions/ACCESS-ESM1-5/member_r5i1p1f1/recon_pC02residual_ACCESS-ESM1-5_member_r5i1p1f1_mon_1x1_200401_202312.zarr
# save path: gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/reconstructions/ACCESS-ESM1-5/member_r5i1p1f1/recon_pCO2_ACCESS-ESM1-5_member_r5i1p1f1_mon_1x1_200401_202312.zarr
# finished with member_r5i1p1f1
# On member member_r1i1p1f1
# pco2T path: gs://leap-persistent/abbysh/pco2_all_members_1982-2023/00_regridded_members/ACCESS-ESM1-5/member_r1i1p1f1/ACCESS-ESM1-5.r1i1p1f1.Omon.zarr
# pco2D path: gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/reconstructions/ACCESS-ESM1-5/member_r1i1p1f1/recon_pC02residual_ACCESS-ESM1-5_member_r1i1p1f1_mon_1x1_200401_202312.zarr
# save path: gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/reconstructions/ACCESS-ESM1-5/member_r1i1p1f1/recon_pCO2_ACCESS-ESM1-5_member_r1i1p1f1_mon_1x1_200401_202312.zarr
# finished with member_r1i1p1f1
# On member member_r10i1p1f1
# pco2T path: gs://leap-persistent/abbysh/pco2_all_members_1982-2023/00_regridded_members/ACCESS-ESM1-5/member_r10i1p1f1/ACCESS-ESM1-5.r10i1p1f1.Omon.zarr
# pco2D path: gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/reconstructions/ACCESS-ESM1-5/member_r10i1p1f1/recon_pC02residual_ACCESS-ESM1-5_member_r10i1p1f1_mon_1x1_200401_202312.zarr
# save path: gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/reconstructions/ACCESS-ESM1-5/member_r10i1p1f1/recon_pCO2_ACCESS-ESM1-5_member_r10i1p1f1_mon_1x1_200401_202312.zarr
# finished with member_r10i1p1f1
# Current ESM: CESM2
# On member member_r4i1p1f1
# pco2T path: gs://leap-persistent/abbysh/pco2_all_members_1982-2023/00_regridded_members/CESM2/member_r4i1p1f1/CESM2.r4i1p1f1.Omon.zarr
# pco2D path: gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/reconstructions/CESM2/member_r4i1p1f1/recon_pC02residual_CESM2_member_r4i1p1f1_mon_1x1_200401_202312.zarr
# save path: gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/reconstructions/CESM2/member_r4i1p1f1/recon_pCO2_CESM2_member_r4i1p1f1_mon_1x1_200401_202312.zarr
# finished with member_r4i1p1f1
# On member member_r11i1p1f1
# pco2T path: gs://leap-persistent/abbysh/pco2_all_members_1982-2023/00_regridded_members/CESM2/member_r11i1p1f1/CESM2.r11i1p1f1.Omon.zarr
# pco2D path: gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/reconstructions/CESM2/member_r11i1p1f1/recon_pC02residual_CESM2_member_r11i1p1f1_mon_1x1_200401_202312.zarr
# save path: gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/reconstructions/CESM2/member_r11i1p1f1/recon_pCO2_CESM2_member_r11i1p1f1_mon_1x1_200401_202312.zarr
# finished with member_r11i1p1f1
# On member member_r10i1p1f1
# pco2T path: gs://leap-persistent/abbysh/pco2_all_members_1982-2023/00_regridded_members/CESM2/member_r10i1p1f1/CESM2.r10i1p1f1.Omon.zarr
# pco2D path: gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/reconstructions/CESM2/member_r10i1p1f1/recon_pC02residual_CESM2_member_r10i1p1f1_mon_1x1_200401_202312.zarr
# save path: gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/reconstructions/CESM2/member_r10i1p1f1/recon_pCO2_CESM2_member_r10i1p1f1_mon_1x1_200401_202312.zarr
# finished with member_r10i1p1f1
# Current ESM: CESM2-WACCM
# On member member_r1i1p1f1
# pco2T path: gs://leap-persistent/abbysh/pco2_all_members_1982-2023/00_regridded_members/CESM2-WACCM/member_r1i1p1f1/CESM2-WACCM.r1i1p1f1.Omon.zarr
# pco2D path: gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/reconstructions/CESM2-WACCM/member_r1i1p1f1/recon_pC02residual_CESM2-WACCM_member_r1i1p1f1_mon_1x1_200401_202312.zarr
# save path: gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/reconstructions/CESM2-WACCM/member_r1i1p1f1/recon_pCO2_CESM2-WACCM_member_r1i1p1f1_mon_1x1_200401_202312.zarr
# finished with member_r1i1p1f1
# On member member_r3i1p1f1
# pco2T path: gs://leap-persistent/abbysh/pco2_all_members_1982-2023/00_regridded_members/CESM2-WACCM/member_r3i1p1f1/CESM2-WACCM.r3i1p1f1.Omon.zarr
# pco2D path: gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/reconstructions/CESM2-WACCM/member_r3i1p1f1/recon_pC02residual_CESM2-WACCM_member_r3i1p1f1_mon_1x1_200401_202312.zarr
# save path: gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/reconstructions/CESM2-WACCM/member_r3i1p1f1/recon_pCO2_CESM2-WACCM_member_r3i1p1f1_mon_1x1_200401_202312.zarr
# finished with member_r3i1p1f1
# On member member_r2i1p1f1
# pco2T path: gs://leap-persistent/abbysh/pco2_all_members_1982-2023/00_regridded_members/CESM2-WACCM/member_r2i1p1f1/CESM2-WACCM.r2i1p1f1.Omon.zarr
# pco2D path: gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/reconstructions/CESM2-WACCM/member_r2i1p1f1/recon_pC02residual_CESM2-WACCM_member_r2i1p1f1_mon_1x1_200401_202312.zarr
# save path: gs://leap-persistent/Mukkke/pco2_residual/nmse/post02_xgb/reconstructions/CESM2-WACCM/member_r2i1p1f1/recon_pCO2_CESM2-WACCM_member_r2i1p1f1_mon_1x1_200401_202312.zarr
# finished with member_r2i1p1f1
# Total execution time: 101.32 seconds

# %% [markdown]
# We concatenate the outputs and ground truth from all members and ESMs into a single dataset, and then use this combined dataset to calculate bias, RMSE, and correlation.

# %%
datasets = []
for ensemble, members in selected_mems_dict.items():
    mems_dict = {ensemble: members}  
    ds = concat_datasets(mems_dict, recon_output_dir = recon_output_dir, init_date = init_date, fin_date=fin_date)
    datasets.append(ds)
concated_dataset = xr.concat(datasets, dim="ens")
evaluator = XarrayEvaluator(concated_dataset)

ds_eval = evaluator.compute_all_metrics()
print(ds_eval)
# Out:
# <xarray.Dataset> Size: 3GB
# Dimensions:      (member: 7, time: 240, xlon: 360, ylat: 180, ens: 3)
# Coordinates:
#   * member       (member) object 56B 'member_r10i1p1f1' ... 'member_r5i1p1f1'
#   * time         (time) datetime64[ns] 2kB 2004-01-01 2004-02-01 ... 2023-12-01
#   * xlon         (xlon) float64 3kB -179.5 -178.5 -177.5 ... 177.5 178.5 179.5
#   * ylat         (ylat) float64 1kB -89.5 -88.5 -87.5 -86.5 ... 87.5 88.5 89.5
#   * ens          (ens) object 24B 'ACCESS-ESM1-5' 'CESM2' 'CESM2-WACCM'
# Data variables:
#     bias         (ens, member, time, ylat, xlon) float64 3GB dask.array<chunksize=(1, 1, 100, 45, 90), meta=np.ndarray>
#     rmse         (ens, member, ylat, xlon) float64 11MB dask.array<chunksize=(1, 1, 45, 90), meta=np.ndarray>
#     correlation  (ens, member, ylat, xlon) float64 11MB dask.array<chunksize=(1, 1, 45, 90), meta=np.ndarray>

# %% [markdown]
# ### 5.1.1 Descriptive Statistics
#
# We can use ds_eval to easily compute descriptive statistics. In this example, we take the average across all time steps and ESMs:
#
# Then, we select the Northern Hemisphere (ylat from 0 to 90), flatten the spatial dimensions, drop missing values, and generate a summary using describe():
#
# This gives us a statistical overview (mean, std, min, max, etc.) of the bias in the Northern Hemisphere.

# %%
ds_eval_mean = (ds_eval['bias']*1).mean('ens').mean('time')
ds_eval_mean.sel(ylat=slice(0,90)).stack(z=['ylat','xlon']).dropna('z').to_dataframe().describe()['bias']
# Out:
# count    83937.000000
# mean        -0.312959
# std          2.920855
# min        -43.928437
# 25%         -1.444040
# 50%         -0.190783
# 75%          1.022203
# max         20.569242
# Name: bias, dtype: float64

# %% [markdown]
# ### 5.1.2 Mean Bias Visualization Across All the Members and ESMs
# Based on this, we could visualize bias between reconstruction and model truth, averaged over the 100 ensemble members, each with a
# monthly resolution over the period init_date through fin_date. Red and blue shading indicates regions where the reconstruction is biased high or low, respectively.

# %%
plot_style = "seaborn-v0_8-talk"

with plt.style.context(plot_style):
    fig = plt.figure(dpi=300) 
    worldmap = SpatialMap2(fig=fig, region='world', 
                           cbar_mode='single',  
                           colorbar=True,  
                           cbar_location='bottom',
                           nrows_ncols=[1,1])
    vrange = [-10, 10, 5] 
    cmap = cm.cm.balance
    
    data = (ds_eval['bias'] * 1).mean('ens').mean('member').mean('time')
    data = data.roll(xlon=len(data.xlon) // 2, roll_coords=True)
    
    data = xr_add_cyclic_point(data, cyclic_coord='xlon') 
    sub = worldmap.add_plot(lon=data['xlon'], lat=data['ylat'], data=data, 
                            vrange=vrange[0:2], cmap=cm.cm.balance, ax=0, linewidth_coast=0.5)
    
    col = worldmap.add_colorbar(sub, ax=0, extend='both')
    worldmap.set_cbar_xlabel(col, 'Mean bias [uatm]', fontsize=14)
    worldmap.set_ticks(col, vrange[0], vrange[1], vrange[2])
    col.ax.tick_params(labelsize=12)
    plt.show()

# %% [markdown]
# ### 5.1.3 Mean Bias Visualization Across All Members for Each ESM

# %%
plot_style = "seaborn-v0_8-talk"
ensemble_means = ds_eval['bias'].mean(dim=['member', 'time'])

ensemble_names = list(ds_eval['ens'].values) 

vrange = [-10,10, 5]
cmap = cm.cm.balance

num_ensemble = len(ensemble_names)  
num_cols = 3  
num_rows = (num_ensemble + num_cols - 1) // num_cols 
with plt.style.context(plot_style):
    fig = plt.figure(dpi=300)
    worldmap = SpatialMap2(fig=fig, region='world', 
                           cbar_mode='single',  
                           colorbar=True,  
                           cbar_location='bottom',
                           nrows_ncols=[num_rows, num_cols]) 
    for i in range(num_ensemble):
        data = ensemble_means.isel(ens=i)
        data = data.roll(xlon=len(data.xlon) // 2, roll_coords=True)  
        data = xr_add_cyclic_point(data, cyclic_coord='xlon') 
        sub = worldmap.add_plot(lon=data['xlon'], lat=data['ylat'], data=data, 
                                vrange=vrange[0:2], cmap=cmap, ax=i, linewidth_coast=0.5)
        worldmap.set_title(title=ensemble_names[i], ax=i, fontsize=14)

    col = worldmap.add_colorbar(sub, ax=0, extend='both')
    worldmap.set_cbar_xlabel(col, 'Mean bias [uatm]', fontsize=14)

    worldmap.set_ticks(col, tmin=vrange[0], tmax=vrange[1], dt=vrange[2])

    col.ax.tick_params(labelsize=12)

    plt.show()

# %% [markdown]
# ### 5.1.4 Number of Months with Observations in Each Grid Cell.

# %%
non_zero_counts = (socat_mask_data.socat_mask != 0).sum(dim="time")
plot_style = "seaborn-v0_8-talk"

with plt.style.context(plot_style):
    fig = plt.figure(dpi=300) 
    worldmap = SpatialMap2(fig=fig, region='world', 
                   cbar_mode='each',
                   colorbar=True,
                   cbar_location='bottom',
                   nrows_ncols=[1,1])
    
    
    vrange = [0, 48, 6]
    cmap = cm.cm.rain
    data = xr_add_cyclic_point(non_zero_counts, cyclic_coord='xlon')
    data = data.assign_coords(xlon=(((data.xlon + 180) % 360) ))
    sub = worldmap.add_plot(lon=data['xlon'], lat=data['ylat'], data=data, 
                      vrange=vrange[0:2], cmap=cmap, ax=0, linewidth_coast=0.5)
    
    col = worldmap.add_colorbar(sub, ax=0,extend='max')
    worldmap.set_cbar_xlabel(col, 'Number of months with data', fontsize=14)
    worldmap.set_ticks(col, vrange[0], vrange[1], vrange[2])
    col.ax.tick_params(labelsize=12)
    plt.show()

# %% [markdown]
# This figure represents the number of months with observational data at each location, which highlights the spatial distribution and density of sampling efforts. The map shows that data coverage is uneven, with some regions, particularly in the Southern Hemisphere and open ocean areas, having significantly fewer observations. Regions with denser observational coverage, such as the Northern Hemisphere, tend to have lower biases in CO2 flux reconstructions compared to sparsely sampled areas like the Southern Ocean.

# %% [markdown]
# ##  5.2 Reconstructed variability on seasonal, sub-decadal, and decadal, compared to original model

# %% [markdown]
# Before computing spatial correlation metrics, we decompose both the reconstructed and reference pCO₂ fields into their long-term trend, seasonal cycle, and residual components using STL-like decomposition. We then evaluate their agreement by calculating gridwise correlation and standard deviation for each component across all ensemble members and ESMs.

# %%
ds_eval_corr = eval_spatial(selected_mems_dict, recon_output_dir, init_date, fin_date)
# Out:
# Starting computation for ESM: ACCESS-ESM1-5, Member: member_r5i1p1f1
# Starting computation for ESM: ACCESS-ESM1-5, Member: member_r1i1p1f1
# Starting computation for ESM: ACCESS-ESM1-5, Member: member_r10i1p1f1
# Starting computation for ESM: CESM2, Member: member_r4i1p1f1
# Starting computation for ESM: CESM2, Member: member_r11i1p1f1
# Starting computation for ESM: CESM2, Member: member_r10i1p1f1
# Starting computation for ESM: CESM2-WACCM, Member: member_r1i1p1f1
# Starting computation for ESM: CESM2-WACCM, Member: member_r3i1p1f1
# Starting computation for ESM: CESM2-WACCM, Member: member_r2i1p1f1
# Total execution time: 224.95 seconds

# %% [markdown]
# Phasing of reconstruction variability on seasonal, sub-decadal, and decadal, compared to original model. Correlation between
# reconstruction and original model on (a) seasonal, (b) sub-decadal, and (c) decadal time scales, averaged across all ensemble members.

# %%
plot_style = "seaborn-v0_8-talk"

with plt.style.context(plot_style):
    # Setup Figure
    fig = plt.figure(dpi=300) 
    worldmap = SpatialMap2(fig=fig, region='world',
                   cbar_mode='edge',
                   axes_pad=0.15,
                   colorbar=True,
                   cbar_location='bottom',
                   nrows_ncols=[3,1])
    
    # Colorbar ranges
    vrange_col1 = [0, 1, 0.2]
    cmap_col1 = cm.cm.oxy
    
    ##-----------------------------------------------------
    ## Ensemble mean
    ##-----------------------------------------------------
    # Correlation - Annual-variation
    data = ds_eval_corr['corr_seasonal'].mean('ens').mean('member')
    data = data.roll(xlon=len(data.xlon) // 2, roll_coords=True)

    data = xr_add_cyclic_point(data, cyclic_coord='xlon')
    sub0 = worldmap.add_plot(lon=data['xlon'], lat=data['ylat'], data=data, 
                            vrange=vrange_col1[0:2], cmap=cmap_col1, ax=0)
    
    
    # Correlation - sub-decadal
    data = ds_eval_corr['corr_residual'].mean('ens').mean('member')
    data = data.roll(xlon=len(data.xlon) // 2, roll_coords=True)
    data = xr_add_cyclic_point(data, cyclic_coord='xlon')
    sub2 = worldmap.add_plot(lon=data['xlon'], lat=data['ylat'], data=data, 
                            vrange=vrange_col1[0:2], cmap=cmap_col1, ax=1)
    
    # Correlation - decadal
    data = ds_eval_corr['corr_dec'].mean('ens').mean('member')
    data = data.roll(xlon=len(data.xlon) // 2, roll_coords=True)
    data = xr_add_cyclic_point(data, cyclic_coord='xlon')
    sub4 = worldmap.add_plot(lon=data['xlon'], lat=data['ylat'], data=data, 
                            vrange=vrange_col1[0:2], cmap=cmap_col1, ax=2)
    
    # add colorbar
    col1 = worldmap.add_colorbar(sub0, ax=0, extend='min')
    worldmap.set_cbar_xlabel(col1, f'Mean correlation')
    worldmap.set_ticks(col1, vrange_col1[0], vrange_col1[1], vrange_col1[2])

    worldmap.grid[0].text(-0.2, 0.5, "Seasonal", transform=worldmap.grid[0].transAxes,
                           fontsize=14, fontweight='bold', va='center', ha='right', rotation=90)
    
    worldmap.grid[1].text(-0.2, 0.5, "Sub-decadal", transform=worldmap.grid[1].transAxes,
                           fontsize=14, fontweight='bold', va='center', ha='right', rotation=90)
    
    worldmap.grid[2].text(-0.2, 0.5, "Decadal", transform=worldmap.grid[2].transAxes,
                           fontsize=14, fontweight='bold', va='center', ha='right', rotation=90)

    
    plt.show()

# %% [markdown]
# At the seasonal scale, the reconstructed CO₂ flux shows the highest correlation with the original model field.
